# %% [markdown]
# # Problem Satement

# %% [markdown]
# The objective of the project is to predict fraudulent credit card transactions using machine learning models. This is crucial from the bank’s as well as customer’s perspective. The banks cannot afford to lose their customers’ money to fraudsters. Every fraud is a loss to the bank as the bank is responsible for the fraud transactions.
#
# The dataset contains transactions made over a period of two days in September 2013 by European credit cardholders. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions. We need to take care of the data imbalance while building the model and come up with the best model by trying various algorithms.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Satement" data-toc-modified-id="Problem-Satement-1">Problem Satement</a></span><ul class="toc-item"><li><span><a href="#Credit-Card-Fraud-Detection" data-toc-modified-id="Credit-Card-Fraud-Detection-1.1">Credit Card Fraud Detection</a></span></li><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-1.2">Importing Libraries</a></span></li><li><span><a href="#Custom-Functions" data-toc-modified-id="Custom-Functions-1.3">Custom Functions</a></span></li><li><span><a href="#Reading-and-Understanding-Data" data-toc-modified-id="Reading-and-Understanding-Data-1.4">Reading and Understanding Data</a></span></li><li><span><a href="#Exploratory-data-analysis" data-toc-modified-id="Exploratory-data-analysis-1.5">Exploratory data analysis</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-1.5.0.1">Univariate Analysis</a></span></li></ul></li><li><span><a href="#Segmented-Univariate-for-Continuous-variables" data-toc-modified-id="Segmented-Univariate-for-Continuous-variables-1.5.1">Segmented Univariate for Continuous variables</a></span><ul class="toc-item"><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-1.5.1.1">Bivariate Analysis</a></span></li></ul></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-1.5.2">Train-Test Split</a></span><ul class="toc-item"><li><span><a href="#Perform-scaling-on-the-Amount-field" data-toc-modified-id="Perform-scaling-on-the-Amount-field-1.5.2.1">Perform scaling on the Amount field</a></span></li></ul></li><li><span><a href="#Plot-Variable-Distribution" data-toc-modified-id="Plot-Variable-Distribution-1.5.3">Plot Variable Distribution</a></span></li><li><span><a href="#Handle-Skewness" data-toc-modified-id="Handle-Skewness-1.5.4">Handle Skewness</a></span></li></ul></li><li><span><a href="#Model-Building-Without-Class-Balancing" data-toc-modified-id="Model-Building-Without-Class-Balancing-1.6">Model Building Without Class Balancing</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-1.6.1">Logistic Regression</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-1.6.2">Decision Tree</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-1.6.3">XGBoost</a></span></li><li><span><a href="#Choose-Best-Model-Without-Balancing" data-toc-modified-id="Choose-Best-Model-Without-Balancing-1.6.4">Choose Best Model Without Balancing</a></span></li><li><span><a href="#Best-Model" data-toc-modified-id="Best-Model-1.6.5">Best Model</a></span><ul class="toc-item"><li><span><a href="#Important-Features" data-toc-modified-id="Important-Features-1.6.5.1">Important Features</a></span></li></ul></li></ul></li><li><span><a href="#Model-building-with-Balanced-Classes" data-toc-modified-id="Model-building-with-Balanced-Classes-1.7">Model building with Balanced Classes</a></span><ul class="toc-item"><li><span><a href="#Random-Oversampling" data-toc-modified-id="Random-Oversampling-1.7.1">Random Oversampling</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-1.7.1.1">Logistic Regression</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-1.7.1.2">Decision Tree</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-1.7.1.3">XGBoost</a></span></li></ul></li><li><span><a href="#SMOTE" data-toc-modified-id="SMOTE-1.7.2">SMOTE</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-1.7.2.1">Logistic Regression</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-1.7.2.2">Decision Tree</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-1.7.2.3">XGBoost</a></span></li></ul></li><li><span><a href="#ADASYN" data-toc-modified-id="ADASYN-1.7.3">ADASYN</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-1.7.3.1">Logistic Regression</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-1.7.3.2">Decision Tree</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-1.7.3.3">XGBoost</a></span></li></ul></li><li><span><a href="#Choose-Best-Model-with-Balanced-Dataset" data-toc-modified-id="Choose-Best-Model-with-Balanced-Dataset-1.7.4">Choose Best Model with Balanced Dataset</a></span></li><li><span><a href="#Best-Model" data-toc-modified-id="Best-Model-1.7.5">Best Model</a></span><ul class="toc-item"><li><span><a href="#Important-Features" data-toc-modified-id="Important-Features-1.7.5.1">Important Features</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.7.6">Summary</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Credit Card Fraud Detection
#
# In this project you will predict fraudulent credit card transactions with the help of Machine learning models. Please import the following libraries to get started.

# %% [markdown]
# ## Importing Libraries

# %%
# Suppress warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import metrics
from sklearn import preprocessing


from xgboost import XGBClassifier


from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score,recall_score,f1_score,roc_auc_score,accuracy_score


import time

from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %% [markdown]
# ## Custom Functions

# %%
# Code to inspect dataframe and percentage missing values in rows and columns

def inspect_df(df):
    print('Shape: {0}'.format(df.shape),end='\n\n')    
    print()
    print("Duplicates: {0}".format(len(df[df.duplicated()])),end='\n')
    print()
    col_types=df.dtypes
    col_missing_count = df.isnull().sum()
    col_missing_pct = round(100*(df.isnull().sum()/len(df.index)),2)
    col_unique_values = df.nunique(axis=0)    
    obj = pd.DataFrame({'Columns':df.columns,'Data_Type':col_types,'Missing_Count':col_missing_count,'Missing_Percent':col_missing_pct,'Unique_Values':col_unique_values}).set_index('Columns')       
    
    return obj

# %%
# ROC Curve function

def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
def get_model_metrics(y_true, y_pred):
    precision_recall_fscore_support(y_true, y_pred)

# %% [markdown]
# ## Reading and Understanding Data

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
inspect = inspect_df(df)
inspect.sort_values(by='Missing_Percent',ascending=False)
# Out:
# Shape: (284807, 31)
#
#
# Duplicates: 1081
#         Data_Type  Missing_Count  Missing_Percent  Unique_Values
# Columns
# Time      float64              0              0.0         124592
# V16       float64              0              0.0         275663
# Amount    float64              0              0.0          32767
# V28       float64              0              0.0         275663
# V27       float64              0              0.0         275663
# V26       float64              0              0.0         275663
# V25       float64              0              0.0         275663
# V24       float64              0              0.0         275663
# V23       float64              0              0.0         275663
# V22       float64              0              0.0         275663
# V21       float64              0              0.0         275663
# V20       float64              0              0.0         275663
# V19       float64              0              0.0         275663
# ...

# %% [markdown]
# Here we will observe the distribution of our classes

# %%
classes=df['Class'].value_counts()
normal_share=classes[0]/df['Class'].count()*100
fraud_share=classes[1]/df['Class'].count()*100

# %%
normal_share
# Out:
# 99.82725143693798

# %%
fraud_share
# Out:
# 0.1727485630620034

# %%
classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# <b> We have only 492 fraud transactions compared to 284315 non-fraud transactions</b>

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# #### Univariate Analysis

# %%
# Create a bar plot for the number and percentage of fraudulent vs non-fraudulent transcations

sns.barplot(x= classes.index, y = classes.values)
plt.show()

# %%
ax = sns.barplot(x="Class", y="Class", data=df, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
plt.show()

# %% [markdown]
# <b> We can see that there a huge class imbalance in the data </b>

# %%
# Create a scatter plot to observe the distribution of classes with time

plt.figure(figsize=(17,6))
plt.subplot(1,2,1)
sns.scatterplot('Class','Time', data=df)
plt.show()

# %% [markdown]
# No pattern can be seen when plotting fraud transactions with Time. This column can be dropped if its not used in further analysis

# %%
# Create a scatter plot to observe the distribution of classes with Amount

plt.figure(figsize=(17,6))
plt.subplot(1,2,1)
sns.scatterplot('Class','Amount', data=df)
plt.show()

# %% [markdown]
# We can see that fraud transactions occur mostly of lower amount value

# %%
# Drop unnecessary columns
# Drop the time column as it is not absolute time but time from first transactions and so not very useful

df.drop('Time',axis = 1,inplace=True)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
#observe the different feature type present in the data

df.describe(percentiles = [0.01,.25,.5,.75,.90,.95,.99])
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15 -1.552563e-15
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 1%    -6.563199e+00 -4.960300e+00 -3.978377e+00 -3.122987e+00 -3.060396e+00
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# 90%    2.015409e+00  1.326635e+00  1.676173e+00  1.482807e+00  1.407893e+00
# 95%    2.081223e+00  1.808585e+00  2.062635e+00  2.566501e+00  2.098960e+00
# 99%    2.237130e+00  3.801811e+00  2.728434e+00  4.248032e+00  3.424903e+00
# ...

# %%
# Plot boxplots for numerical variables

plt.figure(figsize = (20,80))
indx = 1
for col in df.columns:
    plt.subplot(33,3,indx)
    sns.boxplot(y= col,x='Class', data = df)
    plt.title(col)
    indx += 1
plt.show()

# %% [markdown]
# ##### We can clearly see a lot of outliers for each column, segregated on the basis of class

# %% [markdown]
# ###  Segmented Univariate for Continuous variables

# %%
data_Fraud = df[(df.Class == 1)]
data_NonFraud = df[(df.Class == 0)]

col = ['V'+str(i) for i in range(1,29)]
col.append('Amount')
index = 1
plt.figure(figsize=(20,80))
for c in col:
    plt.subplot(15,2,index) 
    sns.distplot(data_Fraud[c],hist=False, label = 'Fraud')
    sns.distplot(data_NonFraud[c],hist=False, label = 'Not Fraud')
    plt.legend(loc='upper right')
    index += 1
plt.show()

# %% [markdown]
# We can notice certain unqiue pattern in fraud cases to that of non-fraud cases.
# - Chances for not a fraud is more if V1, V2, V4 is more than 0.15 and if V3 and V5 is more than 0.10
# - Similarly we notice distinguishbale pattern for other features like V7,V8,V9,..V17,V18,V19,V27,V28 etc.
# - Interestingly, we can also notice most of the frauds is for lower amount.

# %% [markdown]
# #### Bivariate Analysis

# %%
# # pairwise scatter plot
plt.figure(figsize=(16,10))

plt.subplot(2,2,1)
ax = sns.scatterplot('V1', 'V2',hue='Class', data=df)

plt.subplot(2,2,2)
ax = sns.scatterplot('V3', 'V4',hue = 'Class', data=df)

plt.subplot(2,2,3)
ax = sns.scatterplot('V5', 'V6',hue='Class', data=df)

plt.subplot(2,2,4)
ax = sns.scatterplot('V6', 'V7',hue='Class', data=df)

# %% [markdown]
#  We can observe the features are linearly dependent on each other, V6 and V7 has a good positive correlation
#  We can see a linear pattern between the columns V5 and V6 with negative colinearity.

# %%
# # pairwise scatter plot
plt.figure(figsize=(16,10))

plt.subplot(2,2,1)
ax = sns.scatterplot('V8', 'V9',hue='Class', data=df)

plt.subplot(2,2,2)
ax = sns.scatterplot('V10', 'V11',hue = 'Class', data=df)

plt.subplot(2,2,3)
ax = sns.scatterplot('V12', 'V13',hue='Class', data=df)

plt.subplot(2,2,4)
ax = sns.scatterplot('V14', 'V15',hue='Class', data=df)

# %% [markdown]
# <b> We can clearly see a pattern between classes in the feature scatter plot.</b>

# %%
## Correlation Heatmap

plt.figure(figsize = (20,20))
ax = sns.heatmap(df.corr(),cmap="YlGnBu", annot=True,square=True)
bottom, top = ax.get_ylim()
plt.xticks(rotation= 30) 
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.yticks(rotation= 0) 
plt.show()

# %% [markdown]
# ##### We don't see any very strong correlation between columns , so we are not concerned about collinearity here.

# %% [markdown]
# ### Train-Test Split

# %%
y= df.pop('Class')
X = df

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 42,stratify = y)

# %%
print(np.sum(y))
print(np.sum(y_train))
print(np.sum(y_test))
# Out:
# 492
# 394
# 98

# %%
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 265518  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933 -1.479661
# 180305  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697 -0.002192
# 42664  -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261 -2.212603
# 198723  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339 -1.427984
# 82325  -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490  0.504347
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 265518  1.139880  1.406819 -0.157403  ... -0.134435  0.076197  0.297537
# 180305  0.674782  0.045826  0.284864  ... -0.227279  0.038628  0.228197
# 42664  -5.037523  0.000772 -2.009561  ...  1.280856 -2.798352  0.109526
# 198723  0.010010 -1.118447  1.756121  ... -0.490642 -0.139670  0.077013
# 82325  -0.113817 -0.044782 -0.558955  ... -0.275297 -0.243245 -0.173298
#
# ...

# %% [markdown]
# #### Perform scaling on the Amount field

# %%
from sklearn.preprocessing import StandardScaler

# Transform the train data
scaler = StandardScaler()
X_train['Amount'] = scaler.fit_transform(np.array(X_train['Amount']).reshape(-1, 1))

# Transform the test data
X_test['Amount'] = scaler.fit_transform(np.array(X_test['Amount']).reshape(-1, 1))

# %%
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 265518  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933 -1.479661
# 180305  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697 -0.002192
# 42664  -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261 -2.212603
# 198723  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339 -1.427984
# 82325  -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490  0.504347
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 265518  1.139880  1.406819 -0.157403  ... -0.134435  0.076197  0.297537
# 180305  0.674782  0.045826  0.284864  ... -0.227279  0.038628  0.228197
# 42664  -5.037523  0.000772 -2.009561  ...  1.280856 -2.798352  0.109526
# 198723  0.010010 -1.118447  1.756121  ... -0.490642 -0.139670  0.077013
# 82325  -0.113817 -0.044782 -0.558955  ... -0.275297 -0.243245 -0.173298
#
# ...

# %% [markdown]
# ### Plot Variable Distribution

# %%
# plot the histogram of a variable from the dataset to see the skewness

plt.figure(figsize = (20,120))
indx = 1
for col in df.columns:
    plt.subplot(33,3,indx)
    sns.distplot(X_train[col],label=col)
#     plt.title(col)
    indx += 1
plt.show()

# %%
# Find skewness of features

skewed_cols = []

for col in X_train.columns:    
    skew = round((X_train[col].skew()), ndigits=3)
    if(abs(skew)>1):
        skewed_cols.append(col)        

skewed_cols
# Out:
# ['V1',
#  'V2',
#  'V3',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V10',
#  'V12',
#  'V14',
#  'V16',
#  'V17',
#  'V20',
#  'V21',
#  'V23',
#  'V28',
#  'Amount']

# %% [markdown]
# ### Handle Skewness

# %%
# - Use Power Transformer to fit & transform the train & test data

powerTransformer = preprocessing.PowerTransformer(copy=False)
X_train[skewed_cols] =  powerTransformer.fit_transform(X_train[skewed_cols])

X_test[skewed_cols] =  powerTransformer.transform(X_test[skewed_cols])

# %%
# plot the histogram of a variable from the dataset to see the skewness

plt.figure(figsize = (20,120))
indx = 1
for col in skewed_cols:
    plt.subplot(33,3,indx)
    sns.distplot(X_train[col],label=col)
#     plt.title(col)
    indx += 1
plt.show()

# %% [markdown]
# ## Model Building Without Class Balancing

# %% [markdown]
# Metric selection for heavily imbalanced data >br/>
# As we have seen that the data is heavily imbalanced, where only 0.17% transctions are fraudulent, we should not consider Accuracy as a good measure for evaluating the model. Because in the case of all the datapoints return a particular class(1/0) irrespective of any prediction, still the model will result more than 99% Accuracy.
#
# We are going to compare model performance based on F1 score and ROC curve.
#
# Why SVM,KNN was not used for model building ? <br/>
# They do not perform well when we have large data set because the required training time is higher and it takes a lot of computational power.
#
# Why RandomForest was not used for model building?<br/>
# Mainly due to system constraints , we chose to use XGBoost as it shower better inital performance in this data than RandomForest
#
# We are using Logistic Regression,Decision Tree and XGBoost for model building.

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=42)

solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l1','l2']
c_values = [0.2,0.3,0.4]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = StratifiedKFold(n_splits=5, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1,verbose = 1, cv=cv, scoring='f1')
grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:   46.4s finished
# Best: 0.752189 using {'C': 0.3, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.2, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.2, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.751432 (0.010592) with: {'C': 0.2, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.749983 (0.006570) with: {'C': 0.2, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.749983 (0.006570) with: {'C': 0.2, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.749211 (0.009454) with: {'C': 0.2, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.3, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.3, 'penalty': 'l1', 'solver': 'lbfgs'}
# ...

# %%
grid_result.best_params_
# Out:
# {'C': 0.3, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
logisticModel = LogisticRegression(C = 0.3, penalty='l1', solver = 'liblinear')

logisticModel = logisticModel.fit(X_train,y_train)

# %%
X_train_cv = X_train
y_train_cv = logisticModel.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = logisticModel.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train, logisticModel.predict(X_train_cv))

# %%
# Train metrics
print(classification_report(y_train, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       0.90      0.65      0.76       394
#
#     accuracy                           1.00    227845
#    macro avg       0.95      0.83      0.88    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
# Predicted probability
y_pred_proba =logisticModel.predict(X_test_cv)

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test, y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.68      0.75        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.84      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
results = pd.DataFrame({'Method':['W/O Balancing: Logistic Regression'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = results[['Method', 'Precision', 'Recall','F1-Score', 'AUC', 'Accuracy']]
results
# Out:
#                                Method  Precision  Recall  F1-Score    AUC  \
# 0  W/O Balancing: Logistic Regression      82.72   68.37     74.86  84.17
#
#    Accuracy
# 0     99.92

# %% [markdown]
# ##### We can see a good Accuracy of 99%, but we won't relying on accuracy score we have got a good Roc curve AUC = 0.84 and F1 Score of 75. We will be taking this model as a baseline to compare on other models.

# %% [markdown]
# ### Decision Tree

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier

# Create the parameter grid
param_grid = { 'max_depth': range(2,6),
              'min_samples_leaf': range(3, 7, 2),
              'min_samples_split': range(1, 5, 2),
              'criterion': ["gini","entropy"] }


n_folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Instantiate the grid search model
dtree = DecisionTreeClassifier(random_state=42) 
grid_search = GridSearchCV(estimator = dtree, param_grid = param_grid,scoring="f1", cv = n_folds, verbose = 1, n_jobs=-1)

# Fit the grid search to the data
grid_result =grid_search.fit(X_train,y_train)


# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:   29.0s finished
# Best: 0.836817 using {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 3}
# nan (nan) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 1}
# 0.773583 (0.009612) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 3}
# nan (nan) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 1}
# 0.773583 (0.009612) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 3}
# nan (nan) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 3, 'min_samples_split': 1}
# ...

# %%
grid_result.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 5,
#  'min_samples_split': 3}

# %%
# printing the optimal accuracy score and hyperparameters
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=5,
#                        min_samples_split=3, random_state=42)

# %%
# Running the model with best parameters obtained from grid search.

# model with optimal hyperparameters
dtModel = DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=3,
                       random_state=42) 
dtModel = dtModel.fit(X_train, y_train)

# %%
X_train_cv = X_train
y_train_cv = dtModel.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = dtModel.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train, dtModel.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       0.95      0.78      0.86       394
#
#     accuracy                           1.00    227845
#    macro avg       0.98      0.89      0.93    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
# Predicted probability
y_pred_proba =dtModel.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test, y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.88      0.79      0.83        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.89      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['W/O Balancing: Decision Tree'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                          Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  W/O Balancing: Decision Tree       87.5   78.57      82.8  89.28     99.94

# %% [markdown]
# ##### We can see a good Roc curve AUC = 0.94 and F1 Score of 82. we can also we good improvement from the Logistic Regression model.

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier

# Create the parameter grid based on the results of random search 

# define model and parameters
model = XGBClassifier(random_state=42)

# define grid search
grid = {
    'max_depth': [7,8,9],    
    'n_estimators': [172,173,174]     
}

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='f1',verbose = 1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:  3.9min finished
# Best: 0.854157 using {'max_depth': 8, 'n_estimators': 173}
# 0.848811 (0.023854) with: {'max_depth': 7, 'n_estimators': 172}
# 0.848811 (0.023854) with: {'max_depth': 7, 'n_estimators': 173}
# 0.848811 (0.023854) with: {'max_depth': 7, 'n_estimators': 174}
# 0.853018 (0.028149) with: {'max_depth': 8, 'n_estimators': 172}
# 0.854157 (0.026686) with: {'max_depth': 8, 'n_estimators': 173}
# 0.853018 (0.028149) with: {'max_depth': 8, 'n_estimators': 174}
# 0.850629 (0.022465) with: {'max_depth': 9, 'n_estimators': 172}
# 0.850629 (0.022465) with: {'max_depth': 9, 'n_estimators': 173}
# 0.850629 (0.022465) with: {'max_depth': 9, 'n_estimators': 174}

# %%
grid_result.best_params_
# Out:
# {'max_depth': 8, 'n_estimators': 173}

# %%
# model with the best hyperparameters

xgModel = XGBClassifier(max_depth=8,n_estimators=173,random_state=42)

# fit
xgModel = xgModel.fit(X_train,y_train)

# %%
X_train_cv = X_train
y_train_cv = xgModel.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = xgModel.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train, xgModel.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00       394
#
#     accuracy                           1.00    227845
#    macro avg       1.00      1.00      1.00    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
# Predicted probability
y_pred_proba =xgModel.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.83      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['W/O Balancing: XGBoost'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                    Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  W/O Balancing: XGBoost       93.1   82.65     87.57  91.32     99.96

# %% [markdown]
# ##### We can see a good Roc curve AUC = 0.97 and F1 Score of 87. we can also we good improvement from the Decision Tree model.

# %% [markdown]
# ### Choose Best Model Without Balancing

# %% [markdown]
# Let's compare the ROC curve area and metrics of the three models

# %%
plt.figure(figsize=(5, 5))

fpr, tpr, thresholds = metrics.roc_curve( y_test, logisticModel.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, logisticModel.predict(X_test) )    
    
plt.plot( fpr, tpr, label='Logistic Regression (area = %0.2f)' % auc_score )

fpr, tpr, thresholds = metrics.roc_curve( y_test, dtModel.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, dtModel.predict(X_test) )
plt.plot( fpr, tpr, label='Decision Tree (area = %0.2f)' % auc_score )


fpr, tpr, thresholds = metrics.roc_curve( y_test, xgModel.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, xgModel.predict(X_test) )
plt.plot( fpr, tpr, label='XGBoost (area = %0.2f)' % auc_score )


plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
results
# Out:
#                                Method  Precision  Recall  F1-Score    AUC  \
# 0  W/O Balancing: Logistic Regression      82.72   68.37     74.86  84.17
# 0        W/O Balancing: Decision Tree      87.50   78.57     82.80  89.28
# 0              W/O Balancing: XGBoost      93.10   82.65     87.57  91.32
#
#    Accuracy
# 0     99.92
# 0     99.94
# 0     99.96

# %% [markdown]
# <b> We can see that the XGBoost model has the highest ROC AUC as 91.32 and F1-SCore as 87.57 and so we will use this as the best model without class balancing</b>

# %% [markdown]
# ### Best Model

# %%
#initialise the model with optimum hyperparameters for XGBoost model
clf = XGBClassifier(max_depth=8,n_estimators=173,random_state=42)  
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=173, n_jobs=0, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Predict on Train Set
X_train_cv = X_train
y_train_cv = clf.predict(X_train_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train, clf.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00       394
#
#     accuracy                           1.00    227845
#    macro avg       1.00      1.00      1.00    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
print('Train auc =', metrics.roc_auc_score(y_train, y_train_cv))
fpr, tpr, thresholds = metrics.roc_curve(y_train, y_train_cv)
threshold = thresholds[np.argmax(tpr-fpr)]
print(threshold)
# Out:
# Train auc = 1.0
# 1

# %% [markdown]
# We can see that the XGBoost is overfitting since ROC curve has area 1 , we can go with default threshold and no optimal cutoff point required.

# %%
# Predict on Test Set
X_test_cv = X_test
y_test_cv = clf.predict(X_test_cv)

# %%
# Predicted probability
y_pred_proba =clf.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.83      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# #### Important Features

# %%
var_imp = []
for i in clf.feature_importances_:
    var_imp.append(i)
print('Top var =', var_imp.index(np.sort(clf.feature_importances_)[-1])+1)
print('2nd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-2])+1)
print('3rd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-3])+1)

# Variable on Index-17 and Index-14 seems to be the top 2 variables
top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-1])
second_top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-2])

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]

np.random.shuffle(X_train_0)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 20]

plt.scatter(X_train_1[:, top_var_index], X_train_1[:, second_top_var_index], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], top_var_index], X_train_0[:X_train_1.shape[0], second_top_var_index],
            label='Actual Class-0 Examples')
plt.legend()
plt.show()
# Out:
# Top var = 17
# 2nd Top var = 14
# 3rd Top var = 10

# %%
# Create barchart for feature importances

features = X_train.columns
importances = clf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ##### We have plotted the feature importance in descending order, clearly V17 is most important feature.

# %% [markdown]
# ## Model building with Balanced Classes

# %% [markdown]
# As we see that the data is heavily imbalanced, We will try several approaches for handling data imbalance.
# - Oversampling :- Here we will make the same count of non-fraudulent transctions as fraudulent transctions.
# - SMOTE :- Synthetic minority oversampling technique. It is another oversampling technique, which uses nearest neighbor algorithm to create synthetic data.
# - Adasyn:- This is similar to SMOTE with minor changes that the new synthetic data is generated on the region of low density of imbalanced data points.

# %% [markdown]
# ### Random Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

X_rm_sampled,y_rm_sampled = ros.fit_resample(X_train,y_train)

# %%
from collections import Counter
print(sorted(Counter(y_rm_sampled).items()))
# Out:
# [(0, 227451), (1, 227451)]

# %% [markdown]
# We can see that both the classes are balanced now

# %% [markdown]
# #### Logistic Regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()


# define grid search
grid = {
    'solver': ['newton-cg', 'lbfgs', 'liblinear'],    
    'penalty': ['l1','l2'],
    'C': [0.2,0.3,0.4] }

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1,verbose = 1, cv=cv, scoring='f1')
grid_result = grid_search.fit(X_rm_sampled, y_rm_sampled)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:   49.3s finished
# Best: 0.950120 using {'C': 0.4, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.2, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.2, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.950103 (0.000237) with: {'C': 0.2, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.950060 (0.000217) with: {'C': 0.2, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.950058 (0.000214) with: {'C': 0.2, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.950065 (0.000216) with: {'C': 0.2, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.3, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.3, 'penalty': 'l1', 'solver': 'lbfgs'}
# ...

# %%
grid_result.best_params_
# Out:
# {'C': 0.4, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
logisticModel_ro = LogisticRegression(C = 0.3, penalty='l1', solver = 'liblinear')

logisticModel_ro = logisticModel_ro.fit(X_rm_sampled,y_rm_sampled)

# %%
X_train_cv = X_rm_sampled
y_train_cv = logisticModel_ro.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = logisticModel_ro.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_rm_sampled, logisticModel_ro.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_rm_sampled, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95    227451
#            1       0.97      0.93      0.95    227451
#
#     accuracy                           0.95    454902
#    macro avg       0.95      0.95      0.95    454902
# weighted avg       0.95      0.95      0.95    454902

# %%
# Predicted probability
y_pred_proba =logisticModel_ro.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.95      0.54     56962
# weighted avg       1.00      0.97      0.98     56962

# %%
tempResults = pd.DataFrame({'Method':['Random Oversampling: Logistic Regression'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                                      Method  Precision  Recall  F1-Score  \
# 0  Random Oversampling: Logistic Regression       5.45   91.84      10.3
#
#      AUC  Accuracy
# 0  94.55     97.25

# %% [markdown]
# <b>We get good improvement on the ROC curve with AUC = 0.97, which is good improvement on the Logistic Regression without balancing.</b>

# %% [markdown]
# #### Decision Tree

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier


# Create the parameter grid
param_grid = { 'max_depth': range(5, 15, 5),
              'min_samples_leaf': range(3, 10, 2),
              'min_samples_split': range(3, 20, 2),
              'criterion': ["entropy","gini"] }

n_folds = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Instantiate the grid search model
dtree = DecisionTreeClassifier(random_state=42) 
grid_search = GridSearchCV(estimator = dtree, param_grid = param_grid,scoring="f1", cv = n_folds, verbose = 1, n_jobs=-1)

# Fit the grid search to the data
grid_result =grid_search.fit(X_rm_sampled,y_rm_sampled)


# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 432 out of 432 | elapsed:  4.0min finished
# Best: 0.996659 using {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.962461 (0.002475) with: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.962461 (0.002475) with: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.962461 (0.002475) with: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 7}
# 0.962461 (0.002475) with: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 9}
# ...

# %%
grid_result.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'min_samples_leaf': 7,
#  'min_samples_split': 3}

# %%
# printing the optimal accuracy score and hyperparameters
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=7,
#                        min_samples_split=3, random_state=42)

# %%
# Running the model with best parameters obtained from grid search.

# model with optimal hyperparameters
dtModel_ro = DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=7,
                       min_samples_split=3, random_state=42) 
dtModel_ro = dtModel_ro.fit(X_rm_sampled, y_rm_sampled)

# %%
X_train_cv = X_rm_sampled
y_train_cv = dtModel_ro.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = dtModel_ro.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_rm_sampled, dtModel_ro.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_rm_sampled, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227451
#            1       0.99      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902

# %%
# Predicted probability
y_pred_proba =dtModel_ro.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.18      0.81      0.29        98
#
#     accuracy                           0.99     56962
#    macro avg       0.59      0.90      0.64     56962
# weighted avg       1.00      0.99      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['Random Oversampling: Decision Tree'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                                Method  Precision  Recall  F1-Score    AUC  \
# 0  Random Oversampling: Decision Tree      17.52   80.61     28.78  89.98
#
#    Accuracy
# 0     99.31

# %% [markdown]
# ##### We can see a poor F1 score of 29 with good AUC = 90

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier

# Create the parameter grid based on the results of random search 

# define model and parameters
model = XGBClassifier(random_state=42)

# define grid search
grid = {
    'max_depth': [6,7,8],
    'n_estimators': [205,206,207]    
}

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='f1',verbose = 1)
grid_result = grid_search.fit(X_rm_sampled, y_rm_sampled)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed: 10.4min finished
# Best: 0.999921 using {'max_depth': 7, 'n_estimators': 205}
# 0.999901 (0.000016) with: {'max_depth': 6, 'n_estimators': 205}
# 0.999901 (0.000016) with: {'max_depth': 6, 'n_estimators': 206}
# 0.999901 (0.000016) with: {'max_depth': 6, 'n_estimators': 207}
# 0.999921 (0.000025) with: {'max_depth': 7, 'n_estimators': 205}
# 0.999921 (0.000025) with: {'max_depth': 7, 'n_estimators': 206}
# 0.999921 (0.000025) with: {'max_depth': 7, 'n_estimators': 207}
# 0.999908 (0.000019) with: {'max_depth': 8, 'n_estimators': 205}
# 0.999908 (0.000019) with: {'max_depth': 8, 'n_estimators': 206}
# 0.999908 (0.000019) with: {'max_depth': 8, 'n_estimators': 207}

# %%
grid_result.best_params_
# Out:
# {'max_depth': 7, 'n_estimators': 205}

# %%
# model with the best hyperparameters

xgModel_ro = XGBClassifier(max_depth=7,n_estimators=206,random_state=42)

# fit
xgModel_ro = xgModel_ro.fit(X_rm_sampled,y_rm_sampled)

# %%
X_train_cv = X_rm_sampled
y_train_cv = xgModel_ro.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = xgModel_ro.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_rm_sampled, xgModel_ro.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_rm_sampled, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902

# %%
# Predicted probability
y_pred_proba =xgModel_ro.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.89      0.84      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.92      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['Random Oversampling: XGBoost'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                          Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  Random Oversampling: XGBoost      89.13   83.67     86.32  91.83     99.95

# %% [markdown]
# <b> We can see a good F1 score = 86.32 and AUC = 91.83, but not much improvement on without balance xgboost</b>

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)
# Artificial minority samples and corresponding minority labels from SMOTE are appended
# below X_train and y_train respectively
# So to exclusively get the artificial minority samples from SMOTE, we do
X_train_smote_1 = X_train_smote[X_train.shape[0]:]

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]


plt.rcParams['figure.figsize'] = [20, 20]
fig = plt.figure()

plt.subplot(3, 1, 1)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 2)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.scatter(X_train_smote_1.iloc[:X_train_1.shape[0], 0], X_train_smote_1.iloc[:X_train_1.shape[0], 1],
            label='Artificial SMOTE Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 3)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], 0], X_train_0[:X_train_1.shape[0], 1], label='Actual Class-0 Examples')
plt.legend()

plt.show()

# %%
y_train_smote.value_counts()
# Out:
# 1    227451
# 0    227451
# Name: Class, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    227451
# 1       394
# Name: Class, dtype: int64

# %% [markdown]
# #### Logistic Regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()


# define grid search
grid = {
    'solver': ['newton-cg', 'lbfgs', 'liblinear'],    
    'penalty': ['l1','l2'],
    'C': [1,2,3] }

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1,verbose = 1, cv=cv, scoring='f1')
grid_result = grid_search.fit(X_train_smote, y_train_smote)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:   49.5s finished
# Best: 0.947250 using {'C': 2, 'penalty': 'l2', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.947110 (0.001292) with: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.947247 (0.001289) with: {'C': 1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.947247 (0.001289) with: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.947218 (0.001280) with: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 2, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 2, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.947141 (0.001307) with: {'C': 2, 'penalty': 'l1', 'solver': 'liblinear'}
# ...

# %%
grid_result.best_params_
# Out:
# {'C': 2, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
logisticModel_smote = LogisticRegression(C = 2, penalty='l2', solver = 'newton-cg')

logisticModel_smote = logisticModel_smote.fit(X_train_smote,y_train_smote)

# %%
X_train_cv = X_train_smote
y_train_cv = logisticModel_smote.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = logisticModel_smote.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train_smote, logisticModel_smote.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train_smote, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95    227451
#            1       0.97      0.93      0.95    227451
#
#     accuracy                           0.95    454902
#    macro avg       0.95      0.95      0.95    454902
# weighted avg       0.95      0.95      0.95    454902

# %%
# Predicted probability
y_pred_proba =logisticModel_smote.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.94      0.54     56962
# weighted avg       1.00      0.97      0.98     56962

# %%
tempResults = pd.DataFrame({'Method':['SMOTE: Logistic Regression'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                        Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  SMOTE: Logistic Regression       5.11   91.84      9.68  94.45     97.05

# %% [markdown]
# <b> Comparing AUC ,we can see random oversampling logistic regression performed better than SMOTE</b>

# %% [markdown]
# #### Decision Tree

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier


# Create the parameter grid
param_grid = { 'max_depth': [12,13,14],
              'min_samples_leaf': [2,3,4],
              'min_samples_split': [5,6,7],
              'criterion': ["entropy","gini"] }

n_folds = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Instantiate the grid search model
dtree = DecisionTreeClassifier(random_state=42) 
grid_search = GridSearchCV(estimator = dtree, param_grid = param_grid,scoring="f1", cv = n_folds, verbose = 1, n_jobs=-1)

# Fit the grid search to the data
grid_result =grid_search.fit(X_train_smote,y_train_smote)


# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 162 out of 162 | elapsed:  3.9min finished
# Best: 0.994792 using {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.991238 (0.000446) with: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.991249 (0.000445) with: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2, 'min_samples_split': 6}
# 0.991236 (0.000450) with: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2, 'min_samples_split': 7}
# 0.991228 (0.000421) with: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.991228 (0.000421) with: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 6}
# ...

# %%
grid_result.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 14,
#  'min_samples_leaf': 3,
#  'min_samples_split': 5}

# %%
# printing the optimal accuracy score and hyperparameters
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=14, min_samples_leaf=3, min_samples_split=5,
#                        random_state=42)

# %%
# Running the model with best parameters obtained from grid search.

# model with optimal hyperparameters
dtModel_smote = DecisionTreeClassifier(max_depth=14, min_samples_leaf=3, min_samples_split=5,
                       random_state=42) 
dtModel_smote = dtModel_smote.fit(X_train_smote, y_train_smote)

# %%
X_train_cv = X_train_smote
y_train_cv = dtModel_smote.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = dtModel_smote.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train_smote, dtModel_smote.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train_smote, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227451
#            1       0.99      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902

# %%
# Predicted probability
y_pred_proba =dtModel_smote.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.18      0.88      0.30        98
#
#     accuracy                           0.99     56962
#    macro avg       0.59      0.94      0.65     56962
# weighted avg       1.00      0.99      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['SMOTE: Decision Tree'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                  Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  SMOTE: Decision Tree      17.77   87.76     29.55  93.53     99.28

# %% [markdown]
# <b> AUC for SMOTE Decision Tree is better compared to without balancing Decision Tree and Random Oversampling Decsion tree.</b>

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier

# Create the parameter grid based on the results of random search 

# define model and parameters
model = XGBClassifier(random_state=42)

# define grid search
grid = {
    'max_depth': [8,9,10],
    'n_estimators': [197,198,199]   
}

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='f1',error_score=0,verbose = 1)
grid_result = grid_search.fit(X_train_smote, y_train_smote)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed: 17.9min finished
# Best: 0.999785 using {'max_depth': 9, 'n_estimators': 198}
# 0.999776 (0.000014) with: {'max_depth': 8, 'n_estimators': 197}
# 0.999776 (0.000014) with: {'max_depth': 8, 'n_estimators': 198}
# 0.999776 (0.000009) with: {'max_depth': 8, 'n_estimators': 199}
# 0.999782 (0.000023) with: {'max_depth': 9, 'n_estimators': 197}
# 0.999785 (0.000025) with: {'max_depth': 9, 'n_estimators': 198}
# 0.999782 (0.000023) with: {'max_depth': 9, 'n_estimators': 199}
# 0.999747 (0.000032) with: {'max_depth': 10, 'n_estimators': 197}
# 0.999747 (0.000032) with: {'max_depth': 10, 'n_estimators': 198}
# 0.999747 (0.000032) with: {'max_depth': 10, 'n_estimators': 199}

# %%
grid_result.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 198}

# %%
# model with the best hyperparameters

xgModel_smote = XGBClassifier(max_depth=9,n_estimators=198,random_state=42)

# fit
xgModel_smote = xgModel_smote.fit(X_train_smote,y_train_smote)

# %%
X_train_cv = X_train_smote
y_train_cv = xgModel_smote.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = xgModel_smote.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train_smote, xgModel_smote.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train_smote, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902

# %%
# Predicted probability
y_pred_proba =xgModel_smote.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.76      0.85      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.88      0.92      0.90     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['SMOTE: XGBoost'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#            Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  SMOTE: XGBoost      76.15   84.69     80.19  92.32     99.93

# %% [markdown]
# <b> We can see a good F1-score = 80.19 and AUC =92.32, much better than Random Oversampling XgBoost and without balance XgBoost</b>

# %% [markdown]
# ### ADASYN

# %%
import warnings
warnings.filterwarnings("ignore")

from imblearn import over_sampling

ada = over_sampling.ADASYN(random_state=42)
X_train_adasyn, y_train_adasyn = ada.fit_resample(X_train, y_train)
# Artificial minority samples and corresponding minority labels from ADASYN are appended
# below X_train and y_train respectively
# So to exclusively get the artificial minority samples from ADASYN, we do
X_train_adasyn_1 = X_train_adasyn[X_train.shape[0]:]

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]



import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 20]
fig = plt.figure()

plt.subplot(3, 1, 1)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 2)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.scatter(X_train_adasyn_1.iloc[:X_train_1.shape[0], 0], X_train_adasyn_1.iloc[:X_train_1.shape[0], 1],
            label='Artificial ADASYN Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 3)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], 0], X_train_0[:X_train_1.shape[0], 1], label='Actual Class-0 Examples')
plt.legend()

plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()


# define grid search
grid = {
    'solver': ['newton-cg', 'lbfgs', 'liblinear'],    
    'penalty': ['l1','l2'],
    'C': [1,2,3] }

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1,verbose = 1, cv=cv, scoring='f1')
grid_result = grid_search.fit(X_train_adasyn, y_train_adasyn)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  54 | elapsed:   39.5s remaining:   29.3s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  1.9min finished
# Best: 0.889718 using {'C': 2, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.889695 (0.015415) with: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.889712 (0.015448) with: {'C': 1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.889715 (0.015444) with: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.889714 (0.015466) with: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 2, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 2, 'penalty': 'l1', 'solver': 'lbfgs'}
# ...

# %%
grid_result.best_params_
# Out:
# {'C': 2, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
logisticModel_ada = LogisticRegression(C = 2, penalty='l2', solver = 'liblinear')

logisticModel_ada = logisticModel_ada.fit(X_train_adasyn,y_train_adasyn)

# %%
X_train_cv = X_train_adasyn
y_train_cv = logisticModel_ada.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = logisticModel_ada.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train_adasyn, logisticModel_ada.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train_adasyn, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90    227451
#            1       0.91      0.90      0.90    227449
#
#     accuracy                           0.90    454900
#    macro avg       0.90      0.90      0.90    454900
# weighted avg       0.90      0.90      0.90    454900

# %%
# Predicted probability
y_pred_proba =logisticModel_ada.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     56864
#            1       0.02      0.93      0.03        98
#
#     accuracy                           0.91     56962
#    macro avg       0.51      0.92      0.49     56962
# weighted avg       1.00      0.91      0.95     56962

# %%
tempResults = pd.DataFrame({'Method':['ADASYN: Logistic Regression'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                         Method  Precision  Recall  F1-Score   AUC  Accuracy
# 0  ADASYN: Logistic Regression        1.7   92.86      3.34  91.8     90.75

# %% [markdown]
# <b>Comparing AUC, Logistic Regression performed the best for Random Oversampling than other Logisitic models.</b>

# %% [markdown]
# #### Decision Tree

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier


# Create the parameter grid
param_grid = { 'max_depth': [9,10,11],
              'min_samples_leaf': [6,7,8],
              'min_samples_split': [14,15,16],
              'criterion': ["entropy","gini"] }

n_folds = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Instantiate the grid search model
dtree = DecisionTreeClassifier(random_state=42) 
grid_search = GridSearchCV(estimator = dtree, param_grid = param_grid,scoring="f1", cv = n_folds, verbose = 1, n_jobs=-1)

# Fit the grid search to the data
grid_result =grid_search.fit(X_train_adasyn,y_train_adasyn)


# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 162 out of 162 | elapsed:  3.4min finished
# Best: 0.986806 using {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 6, 'min_samples_split': 14}
# 0.977434 (0.000452) with: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6, 'min_samples_split': 14}
# 0.977425 (0.000462) with: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6, 'min_samples_split': 15}
# 0.977425 (0.000462) with: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6, 'min_samples_split': 16}
# 0.977441 (0.000446) with: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 7, 'min_samples_split': 14}
# 0.977433 (0.000457) with: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 7, 'min_samples_split': 15}
# ...

# %%
grid_result.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 11,
#  'min_samples_leaf': 6,
#  'min_samples_split': 14}

# %%
# printing the optimal accuracy score and hyperparameters
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=11, min_samples_leaf=6,
#                        min_samples_split=14, random_state=42)

# %%
# Running the model with best parameters obtained from grid search.

# model with optimal hyperparameters
dtModel_ada = DecisionTreeClassifier(criterion='entropy', max_depth=11, min_samples_leaf=6,
                       min_samples_split=14, random_state=42) 
dtModel_ada = dtModel_ada.fit(X_train_adasyn, y_train_adasyn)

# %%
X_train_cv = X_train_adasyn
y_train_cv = dtModel_ada.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = dtModel_ada.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train_adasyn, dtModel_ada.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train_adasyn, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    227451
#            1       0.98      0.99      0.99    227449
#
#     accuracy                           0.99    454900
#    macro avg       0.99      0.99      0.99    454900
# weighted avg       0.99      0.99      0.99    454900

# %%
# Predicted probability
y_pred_proba =dtModel_ada.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.07      0.81      0.12        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.89      0.56     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
tempResults = pd.DataFrame({'Method':['ADASYN: Decision Tree'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#                   Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  ADASYN: Decision Tree       6.76   80.61     12.47  89.35     98.05

# %% [markdown]
# <b> Comparing AUC, Decision Tree performed the best for SMOTE than other Decision Tree models.</b>

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier

# Create the parameter grid based on the results of random search 

# define model and parameters
model = XGBClassifier()

# define grid search
grid = {
    'max_depth': [7,8,9],
    'n_estimators': [203,204,205]
}

cv = StratifiedKFold(n_splits=3, random_state=42)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='f1',error_score=0,verbose = 1)
grid_result = grid_search.fit(X_train_adasyn, y_train_adasyn)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed: 17.3min finished
# Best: 0.934182 using {'max_depth': 7, 'n_estimators': 205}
# 0.934105 (0.025824) with: {'max_depth': 7, 'n_estimators': 203}
# 0.934058 (0.025694) with: {'max_depth': 7, 'n_estimators': 204}
# 0.934182 (0.025763) with: {'max_depth': 7, 'n_estimators': 205}
# 0.930917 (0.027598) with: {'max_depth': 8, 'n_estimators': 203}
# 0.931040 (0.027551) with: {'max_depth': 8, 'n_estimators': 204}
# 0.931030 (0.027600) with: {'max_depth': 8, 'n_estimators': 205}
# 0.928004 (0.029353) with: {'max_depth': 9, 'n_estimators': 203}
# 0.927936 (0.029492) with: {'max_depth': 9, 'n_estimators': 204}
# 0.927978 (0.029411) with: {'max_depth': 9, 'n_estimators': 205}

# %%
grid_result.best_params_
# Out:
# {'max_depth': 7, 'n_estimators': 205}

# %%
# model with the best hyperparameters

xgModel_ada = XGBClassifier(max_depth=8,n_estimators=204,random_state=42)

# fit
xgModel_ada = xgModel_ada.fit(X_train_adasyn,y_train_adasyn)

# %%
X_train_cv = X_train_adasyn
y_train_cv = xgModel_ada.predict(X_train_cv)

X_test_cv = X_test
y_test_cv = xgModel_ada.predict(X_test_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_train_adasyn, xgModel_ada.predict_proba(X_train_cv)[:,1])

# %%
# Train metrics
print(classification_report(y_train_adasyn, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227449
#
#     accuracy                           1.00    454900
#    macro avg       1.00      1.00      1.00    454900
# weighted avg       1.00      1.00      1.00    454900

# %%
# Predicted probability
y_pred_proba =xgModel_ada.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.79      0.85      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.92      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
tempResults = pd.DataFrame({'Method':['ADASYN: XGBoost'], 'Precision': round(precision_score(y_test, y_test_cv)*100,2),
                        'Recall': round(recall_score(y_test, y_test_cv)*100,2),'F1-Score': round(f1_score(y_test, y_test_cv)*100,2),
                        'AUC': round(roc_auc_score(y_test, y_test_cv)*100,2),'Accuracy': round(accuracy_score(y_test, y_test_cv)*100,2) })
results = pd.concat([results, tempResults])
tempResults
# Out:
#             Method  Precision  Recall  F1-Score    AUC  Accuracy
# 0  ADASYN: XGBoost      79.05   84.69     81.77  92.33     99.94

# %% [markdown]
# <b> Comparing AUC, XgBoost performed the best for Adasyn than other Xgbooost models.</b>

# %% [markdown]
# ### Choose Best Model with Balanced Dataset

# %% [markdown]
# Let's compare the ROC curve area and metrics of the three models with Random Oversampling ,SMOTE and ADASYN

# %%
plt.figure(figsize=(5, 5))

# Random Oversampling

fpr, tpr, thresholds = metrics.roc_curve( y_test, logisticModel_ro.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, logisticModel_ro.predict(X_test) )    
    
plt.plot( fpr, tpr, label='Logistic Regression (area = %0.2f)' % auc_score )

fpr, tpr, thresholds = metrics.roc_curve( y_test, dtModel_ro.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, dtModel_ro.predict(X_test) )
plt.plot( fpr, tpr, label='Decision Tree (area = %0.2f)' % auc_score )


fpr, tpr, thresholds = metrics.roc_curve( y_test, xgModel_ro.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, xgModel_ro.predict(X_test) )
plt.plot( fpr, tpr, label='XGBoost (area = %0.2f)' % auc_score )

# SMOTE

fpr, tpr, thresholds = metrics.roc_curve( y_test, logisticModel_smote.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, logisticModel_smote.predict(X_test) )    
    
plt.plot( fpr, tpr, label='Logistic Regression (area = %0.2f)' % auc_score )

fpr, tpr, thresholds = metrics.roc_curve( y_test, dtModel_smote.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, dtModel_smote.predict(X_test) )
plt.plot( fpr, tpr, label='Decision Tree (area = %0.2f)' % auc_score )


fpr, tpr, thresholds = metrics.roc_curve( y_test, xgModel_smote.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, xgModel_smote.predict(X_test) )
plt.plot( fpr, tpr, label='XGBoost (area = %0.2f)' % auc_score )


# ADASYN

fpr, tpr, thresholds = metrics.roc_curve( y_test, logisticModel_ada.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, logisticModel_ada.predict(X_test) )    
    
plt.plot( fpr, tpr, label='Logistic Regression (area = %0.2f)' % auc_score )

fpr, tpr, thresholds = metrics.roc_curve( y_test, dtModel_ada.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, dtModel_ada.predict(X_test) )
plt.plot( fpr, tpr, label='Decision Tree (area = %0.2f)' % auc_score )


fpr, tpr, thresholds = metrics.roc_curve( y_test, xgModel_ada.predict(X_test),
                                              drop_intermediate = False )
auc_score = metrics.roc_auc_score( y_test, xgModel_ada.predict(X_test) )
plt.plot( fpr, tpr, label='XGBoost (area = %0.2f)' % auc_score )


plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
results
# Out:
#                                      Method  Precision  Recall  F1-Score  \
# 0        W/O Balancing: Logistic Regression      82.72   68.37     74.86
# 0              W/O Balancing: Decision Tree      87.50   78.57     82.80
# 0                    W/O Balancing: XGBoost      93.10   82.65     87.57
# 0  Random Oversampling: Logistic Regression       5.45   91.84     10.30
# 0        Random Oversampling: Decision Tree      17.52   80.61     28.78
# 0              Random Oversampling: XGBoost      89.13   83.67     86.32
# 0                SMOTE: Logistic Regression       5.11   91.84      9.68
# 0                      SMOTE: Decision Tree      17.77   87.76     29.55
# 0                            SMOTE: XGBoost      76.15   84.69     80.19
# 0               ADASYN: Logistic Regression       1.70   92.86      3.34
# 0                     ADASYN: Decision Tree       6.76   80.61     12.47
# 0                           ADASYN: XGBoost      79.05   84.69     81.77
#
# ...

# %% [markdown]
# We can see that the Logistic model with Random Oversampling  has the highest ROC AUC as 94.55 and Recall but low precision resulting in F1-score of 10.30.
# XGBoost with Random Oversampling has the highest F1-SCore as 86.32.
# In this case we choose the XGBoost with RandomOversampling as the Best Model after Class Balancing as it has highest F1-score as well high ROC AUC of 91.83.

# %% [markdown]
# ### Best Model

# %%
# Choose Random Oversampling train data sets and create the Optimal XGBoost model

#initialise the model with optimum hyperparameters
clf = XGBClassifier(max_depth=7,n_estimators=206,random_state=42)  
clf.fit(X_rm_sampled,y_rm_sampled)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=206, n_jobs=0, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Predict on Train Set
X_train_cv = X_rm_sampled
y_train_cv = clf.predict(X_train_cv)

# %%
# Plot the ROC curve for Train set
draw_roc(y_rm_sampled, clf.predict_proba(X_train_cv)[:,1])

# %%
print('Train auc =', metrics.roc_auc_score(y_rm_sampled, clf.predict_proba(X_train_cv)[:,1]))
fpr, tpr, thresholds = metrics.roc_curve(y_rm_sampled, clf.predict_proba(X_train_cv)[:,1])
threshold = thresholds[np.argmax(tpr-fpr)]
print(threshold)
# Out:
# Train auc = 1.0
# 0.9998883

# %% [markdown]
# We can go with default threshold and no optimal cutoff point required.

# %%
# Train metrics
print(classification_report(y_rm_sampled, y_train_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902

# %%
# Predict on Test Set
X_test_cv = X_test
y_test_cv = clf.predict(X_test_cv)

# %%
# Predicted probability
y_pred_proba =clf.predict_proba(X_test_cv)[:,1]

# Plot the ROC curve for test
draw_roc(y_test, y_pred_proba)

# %%
# Test metrics
print(classification_report(y_test,y_test_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.89      0.84      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.92      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# #### Important Features

# %%
var_imp = []
for i in clf.feature_importances_:
    var_imp.append(i)
print('Top var =', var_imp.index(np.sort(clf.feature_importances_)[-1])+1)
print('2nd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-2])+1)
print('3rd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-3])+1)

# Variable on Index-14 and Index-4 seems to be the top 2 variables
top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-1])
second_top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-2])

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]

np.random.shuffle(X_train_0)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 20]

plt.scatter(X_train_1[:, top_var_index], X_train_1[:, second_top_var_index], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], top_var_index], X_train_0[:X_train_1.shape[0], second_top_var_index],
            label='Actual Class-0 Examples')
plt.legend()

plt.show()
# Out:
# Top var = 14
# 2nd Top var = 4
# 3rd Top var = 12

# %%
# Create barchart for feature importances

features = X_train.columns
importances = clf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# <b> Interestingly after balancing the dataset with Random Oversampling, we get the most important feature as V14 which was the second best feature before balancing.</b>

# %% [markdown]
# ### Summary
#
# We created Logistic Regression,Decision Tree and XGBoost models with Imabalaced Data as well as after using oversampling techniques such as RandomOversampling,SMOTE and ADASYN.
#
# Some of the models like Logistic Regression with Oversampling techniques had extremely high value of Recall(>90%) but low Precision . This is useful if Business wants to identify most of the Fraud transactions but downside will be it will also flag a lot of Non Fraud transactions as Fraud and extra money will be spend on validating fraud transations.
#
# This is why we chose F1-score along with ROC AUC value to determine the best model after comparing their metrics, which will give the highest value of both Recall and Precision combined along with a high AUC value.
#
# XGBoost performed the best in both Unbalanced data as well as after balancing the dataset.
# Since the feature names are anonymized , we do not know the exact feature but V14,V4(balanced) and V17(unbalanced) are features which are important to identify fraud transactions for the bank.
