# %%
import nltk

nltk.help.upenn_tagset()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-1-705f0425851f> in <module>
#       1 import nltk
#       2
# ----> 3 nltk.help.upenn_tagset()
#
# ~\Anaconda3\lib\site-packages\nltk\help.py in upenn_tagset(tagpattern)
#      26
#      27 def upenn_tagset(tagpattern=None):
# ---> 28     _format_tagset("upenn_tagset", tagpattern)
#      29
#      30
#
# ~\Anaconda3\lib\site-packages\nltk\help.py in _format_tagset(tagset, tagpattern)
#      45
#      46 def _format_tagset(tagset, tagpattern=None):
# ---> 47     tagdict = load("help/tagsets/" + tagset + ".pickle")
#      48     if not tagpattern:
#      49         _print_entries(sorted(tagdict), tagdict)
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# ...
